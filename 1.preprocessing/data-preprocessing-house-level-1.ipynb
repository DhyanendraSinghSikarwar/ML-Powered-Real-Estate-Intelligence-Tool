# %% [markdown]
# # Preprocessing of Independent Houses file

# %%
# importing libraries
import numpy as np
import pandas as pd

# %%
# Displaying most data
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel('/content/independent-house.xlsx')
df.sample(5)
# Out:
#                                       property_name  \
# 764         6 Bedroom House for sale in DLF Phase 1
# 82   4 Bedroom House for sale in Sector 109 Gurgaon
# 358        1 Bedroom House for sale in Baldev Nagar
# 872     4 Bedroom House for sale in Nirvana Country
# 388        3 Bedroom House for sale in Baldev Nagar
#
#                                                   link  \
# 764  https://www.99acres.com/6-bhk-bedroom-independ...
# 82   https://www.99acres.com/4-bhk-bedroom-independ...
# 358  https://www.99acres.com/1-bhk-bedroom-independ...
# 872  https://www.99acres.com/4-bhk-bedroom-independ...
# 388  https://www.99acres.com/3-bhk-bedroom-independ...
#
#                                  society      price             rate  \
# 764                       DLF City Plots   18 Crore  ₹ 39,841/sq.ft.
# 82   International City by SOBHA Phase 2        NaN  ₹ 13,910/sq.ft.
# 358                                  NaN        NaN   ₹ 7,619/sq.ft.
# ...

# %%
# shape
df.shape
# Out:
# (1095, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    1095 non-null   object
#  1   link             1095 non-null   object
#  2   society          471 non-null    object
#  3   price            968 non-null    object
#  4   rate             1054 non-null   object
#  5   area             1095 non-null   object
#  6   areaWithType     987 non-null    object
#  7   bedRoom          987 non-null    object
#  8   bathroom         987 non-null    object
#  9   balcony          987 non-null    object
#  10  additionalRoom   589 non-null    object
#  11  address          1031 non-null   object
#  12  noOfFloor        967 non-null    object
#  13  facing           674 non-null    object
#  14  agePossession    987 non-null    object
#  15  nearbyLocations  913 non-null    object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(13)

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1082, 21)

# %%
df.isna().sum()
# Out:
# property_name        0
# link                 0
# society            619
# price              127
# rate                41
# area                 0
# areaWithType       108
# bedRoom            108
# bathroom           108
# balcony            108
# additionalRoom     504
# address             64
# noOfFloor          127
# facing             420
# agePossession      108
# nearbyLocations    182
# description         59
# furnishDetails     350
# features           420
# rating             188
# property_id         59
# dtype: int64

# %%
# Rows having null values in more than 13 columns
df[df.isna().sum(axis=1) > 13]
# Out:
#                                           property_name  \
# 60        4 Bedroom House for sale in Sector 86 Gurgaon
# 61    8 Bedroom House for sale in B1 Block Sector 57...
# 62              6 Bedroom House for sale in DLF Phase 1
# 63      6 Bedroom House for sale in Sushant Lok Phase 3
# 64      6 Bedroom House for sale in Sushant Lok Phase 3
# 65              4 Bedroom House for sale in DLF Phase 4
# 66          8 Bedroom House for sale in Uppals Southend
# 67          6 Bedroom House for sale in Uppals Southend
# 68        4 Bedroom House for sale in Sector 48 Gurgaon
# 69              4 Bedroom House for sale in Malibu Town
# 70        5 Bedroom House for sale in Sector 33 Gurgaon
# 71              5 Bedroom House for sale in DLF Phase 1
# 72             3 Bedroom House for sale in South City 1
# 178         4 Bedroom House for sale in Nirvana Country
# 179       5 Bedroom House for sale in Sector 63 Gurgaon
# 180       4 Bedroom House for sale in Sector 81 Gurgaon
# ...

# %%
df[df.isna().sum(axis=1) > 13].shape
# Out:
# (59, 21)

# %%
# we are dropping them
df.drop(index= df[df.isna().sum(axis=1) > 13].index, inplace= True)

# %%
df.shape
# Out:
# (1023, 21)

# %%
# check for missing values
df.isnull().sum()
# Out:
# property_name        0
# link                 0
# society            579
# price               68
# rate                38
# area                 0
# areaWithType        49
# bedRoom             49
# bathroom            49
# balcony             49
# additionalRoom     445
# address              5
# noOfFloor           68
# facing             361
# agePossession       49
# nearbyLocations    123
# description          0
# furnishDetails     291
# features           361
# rating             129
# property_id          0
# dtype: int64

# %% [markdown]
# #### columns to drop
# - There are some columns which we will not use in our analysis:
#
#   1. property_id
#   2. link

# %%
df.sample(3)
# Out:
#                                      property_name  \
# 268         6 Bedroom House for sale in Prem Nagar
# 747  9 Bedroom House for sale in Sector 27 Gurgaon
# 802    5 Bedroom House for sale in Nirvana Country
#
#                                                   link         society  \
# 268  https://www.99acres.com/6-bhk-bedroom-independ...             NaN
# 747  https://www.99acres.com/9-bhk-bedroom-independ...             NaN
# 802  https://www.99acres.com/5-bhk-bedroom-independ...  Unitech Espace
#
#           price             rate                      area  \
# 268      62 Lac  ₹ 32,291/sq.ft.  (18 sq.m.) Built-up Area
# 747     8 Crore  ₹ 26,298/sq.ft.     (283 sq.m.) Plot Area
# 802  10.3 Crore  ₹ 31,790/sq.ft.     (301 sq.m.) Plot Area
#
#                          areaWithType     bedRoom     bathroom       balcony  \
# 268  Built Up area: 192 (17.84 sq.m.)  6 Bedrooms  6 Bathrooms    No Balcony
# ...

# %%
df.drop(columns= ['property_id', 'link'], inplace= True)

# %%
df.sample(3)
# Out:
#                                      property_name             society  \
# 755  4 Bedroom House for sale in Sector 48 Gurgaon  Vipul Tatvam Villa
# 498          3 Bedroom House for sale in Madanpuri          Madan puri
# 563      2 Bedroom House for sale in Garhi Harsaru                 NaN
#
#           price             rate                   area  \
# 755  7.35 Crore  ₹ 22,812/sq.ft.  (299 sq.m.) Plot Area
# 498      75 Lac  ₹ 12,500/sq.ft.   (56 sq.m.) Plot Area
# 563      29 Lac   ₹ 3,254/sq.ft.   (83 sq.m.) Plot Area
#
#                     areaWithType     bedRoom     bathroom      balcony  \
# 755  Plot area 358(299.33 sq.m.)  4 Bedrooms  5 Bathrooms  2 Balconies
# 498   Plot area 600(55.74 sq.m.)  3 Bedrooms  5 Bathrooms  3 Balconies
# 563   Plot area 891(82.78 sq.m.)  2 Bedrooms   1 Bathroom   No Balcony
#
#                                     additionalRoom  \
# 755  Servant Room,Store Room,Study Room,Pooja Room
# 498                                            NaN
# ...

# %%
# Renaming area column
df.rename(columns= {'rate': 'price_per_sqft'}, inplace=True)
df.sample(3)
# Out:
#                                        property_name                  society  \
# 1029  4 Bedroom House for sale in Sector 17B Gurgaon                      NaN
# 394    6 Bedroom House for sale in Sector 17 Gurgaon  IFFCO Nagar and 17B RWA
# 6      5 Bedroom House for sale in Sector 66 Gurgaon       Emaar MGF Marbella
#
#           price   price_per_sqft                   area  \
# 1029  8.5 Crore  ₹ 18,814/sq.ft.  (420 sq.m.) Plot Area
# 394   3.5 Crore  ₹ 24,305/sq.ft.  (134 sq.m.) Plot Area
# 6      12 Crore  ₹ 37,037/sq.ft.  (301 sq.m.) Plot Area
#
#                                            areaWithType     bedRoom  \
# 1029  Plot area 502(419.74 sq.m.)Built Up area: 500 ...  4 Bedrooms
# 394                        Plot area 1440(133.78 sq.m.)  6 Bedrooms
# 6                           Plot area 360(301.01 sq.m.)  5 Bedrooms
#
#          bathroom       balcony                      additionalRoom  \
# 1029  4 Bathrooms   2 Balconies  Pooja Room,Study Room,Servant Room
# ...

# %% [markdown]
# ### Checking Society column

# %%
df['society'].value_counts()
# Out:
# society
# Emaar MGF Marbella                                   26
# International City by SOBHA Phase 2                  26
# Vipul Tatvam Villa                                   24
# International City by Sobha Phase 1                  23
# Unitech Uniworld Resorts                             13
# Unitech Espace                                       11
# DLF City Plots Phase 2                               11
# DLF City Plots                                       11
# Eldeco Mansionz                                       9
# Bptp Visionnaire                                      8
# Not Applicable                                        7
# Uppal Southend4.0 ★                                   7
# Ansals Palam Vihar                                    6
# Sushant Lok 1 Builder Floors                          6
# Experion Windchants3.8 ★                              5
# DLF City Phase 1                                      5
# Ansal Sushant Lok Plots4.1 ★                          4
# ...

# %%
df['society'].nunique()
# Out:
# 185

# %%
import re
df['society'] = df['society'].apply(lambda name: re.sub(r'\d+(\.\d+)?\s?★', '', str(name)).strip()).str.lower()

# %%
df['society'].nunique()
# Out:
# 183

# %%
df['society'].value_counts()
# Out:
# society
# nan                                                  579
# emaar mgf marbella                                    26
# international city by sobha phase 2                   26
# vipul tatvam villa                                    24
# international city by sobha phase 1                   23
# unitech uniworld resorts                              13
# unitech espace                                        11
# dlf city plots                                        11
# dlf city plots phase 2                                11
# eldeco mansionz                                        9
# bptp visionnaire                                       8
# not applicable                                         7
# uppal southend                                         7
# sushant lok 1 builder floors                           6
# ansals palam vihar                                     6
# experion windchants                                    5
# ...

# %% [markdown]
# ### Checking price column

# %%
df['price'].value_counts()
# Out:
# price
# 3.5 Crore           19
# 5.5 Crore           17
# 6.5 Crore           16
# 6 Crore             14
# 4.5 Crore           13
# 5 Crore             13
# 8 Crore             13
# 50 Lac              13
# 75 Lac              13
# 70 Lac              13
# 7 Crore             12
# 8.5 Crore           12
# 85 Lac              12
# 1.5 Crore           11
# 4 Crore             11
# 90 Lac              10
# Price on Request    10
# 2.25 Crore          10
# 45 Lac              10
# 60 Lac              10
# 10 Crore            10
# 2.5 Crore           10
# 9 Crore             10
# 12 Crore             9
# 2 Crore              9
# 80 Lac               9
# 9.5 Crore            9
# 1.1 Crore            9
# 1.7 Crore            9
# 1 Crore              8
# 1.6 Crore            8
# 11 Crore             8
# 6.75 Crore           8
# 4.6 Crore            8
# 3.75 Crore           7
# 1.2 Crore            7
# 55 Lac               7
# 40 Lac               7
# 1.3 Crore            7
# ...

# %%
df[df['price'] == 'Price on Request']
# Out:
#                                          property_name society  \
# 295       2 Bedroom House for sale in Sector 8 Gurgaon     nan
# 296          3 Bedroom House for sale in Dharam Colony     nan
# 325           5 Bedroom House for sale in Laxman Vihar     nan
# 326           3 Bedroom House for sale in Laxman Vihar     nan
# 402          7 Bedroom House for sale in Rajendra Park     nan
# 431            3 Bedroom House for sale in Ansal Plaza     nan
# 494         2 Bedroom House for sale in Sheetla Colony     nan
# 569            5 Bedroom House for sale in Surat Nagar     nan
# 595  2 Bedroom House for sale in Dharam Colony Block E     nan
# 668              4 Bedroom House for sale in Madanpuri     nan
#
#                 price price_per_sqft                       area  \
# 295  Price on Request            NaN   (74 sq.m.) Built-up Area
# 296  Price on Request            NaN     (93 sq.m.) Carpet Area
# 325  Price on Request            NaN  (167 sq.m.) Built-up Area
# ...

# %%
df = df[df['price'] != 'Price on Request']
df = df[df['price'] != 'price']

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad               nan
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               nan
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               nan
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               nan
#
#         price    price_per_sqft                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %%
def modify_price(x):
  if type(x) == float:
    return x
  else:
    if x[1] == 'Lac':
      return round(float(x[0])/100,2)
    else:
      return round(float(x[0]),2)

# %%
df['price'] = df['price'].str.split(' ').apply(modify_price)

# %%
df.head(3)
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad               nan   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               nan   2.10
#
#      price_per_sqft                   area                 areaWithType  \
# 0   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
#
#        bedRoom      bathroom       balcony  \
# 0   5 Bedrooms   4 Bathrooms  3+ Balconies
# 1   5 Bedrooms   4 Bathrooms   2 Balconies
# 2  10 Bedrooms  10 Bathrooms  3+ Balconies
#
#                        additionalRoom  \
# 0                        Servant Room
# 1  Store Room,Pooja Room,Servant Room
# 2                        Servant Room
#
# ...

# %% [markdown]
# ### Checking price_per_sqft column

# %%
df['price_per_sqft'].value_counts()
# Out:
# price_per_sqft
# ₹ 22,222/sq.ft.     14
# ₹ 33,333/sq.ft.     11
# ₹ 11,111/sq.ft.     11
# ₹ 10,000/sq.ft.     10
# ₹ 26,235/sq.ft.      6
# ₹ 31,481/sq.ft.      6
# ₹ 26,667/sq.ft.      6
# ₹ 30,556/sq.ft.      6
# ₹ 37,037/sq.ft.      6
# ₹ 23,333/sq.ft.      5
# ₹ 11,100/sq.ft.      5
# ₹ 5,000/sq.ft.       5
# ₹ 13,333/sq.ft.      5
# ₹ 9,444/sq.ft.       5
# ₹ 23,148/sq.ft.      5
# ₹ 8,889/sq.ft.       5
# ₹ 8,000/sq.ft.       5
# ₹ 34,722/sq.ft.      4
# ₹ 35,000/sq.ft.      4
# ₹ 21,605/sq.ft.      4
# ₹ 9,722/sq.ft.       4
# ₹ 18,889/sq.ft.      4
# ₹ 32,407/sq.ft.      4
# ₹ 24,691/sq.ft.      4
# ₹ 27,778/sq.ft.      4
# ₹ 10,556/sq.ft.      3
# ₹ 8,235/sq.ft.       3
# ₹ 60,000/sq.ft.      3
# ₹ 25,000/sq.ft.      3
# ₹ 15,625/sq.ft.      3
# ₹ 12,000/sq.ft.      3
# ₹ 6,944/sq.ft.       3
# ₹ 5,555/sq.ft.       3
# ₹ 12,222/sq.ft.      3
# ₹ 50,000/sq.ft.      3
# ₹ 33,951/sq.ft.      3
# ₹ 32,222/sq.ft.      3
# ₹ 8,333/sq.ft.       3
# ₹ 13,889/sq.ft.      3
# ...

# %%
df['price_per_sqft'] = df['price_per_sqft'].str.split('/').str.get(0).str.replace('₹','').str.replace(',','').str.strip().astype('float')

# %%
df.head(3)
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad               nan   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               nan   2.10
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
#
#        bedRoom      bathroom       balcony  \
# 0   5 Bedrooms   4 Bathrooms  3+ Balconies
# 1   5 Bedrooms   4 Bathrooms   2 Balconies
# 2  10 Bedrooms  10 Bathrooms  3+ Balconies
#
#                        additionalRoom  \
# 0                        Servant Room
# 1  Store Room,Pooja Room,Servant Room
# 2                        Servant Room
#
# ...

# %% [markdown]
# ### Checking bedrooms column

# %%
df['bedRoom'].value_counts()
# Out:
# bedRoom
# 4 Bedrooms     232
# 5 Bedrooms     194
# 3 Bedrooms     146
# 2 Bedrooms      88
# 6 Bedrooms      81
# 9 Bedrooms      45
# 1 Bedroom       38
# 8 Bedrooms      33
# 7 Bedrooms      31
# 12 Bedrooms     28
# 10 Bedrooms     21
# 16 Bedrooms     12
# 13 Bedrooms      4
# 11 Bedrooms      2
# 19 Bedrooms      2
# 18 Bedrooms      2
# 21 Bedrooms      1
# 20 Bedrooms      1
# 36 Bedrooms      1
# 34 Bedrooms      1
# 14 Bedrooms      1
# Name: count, dtype: int64

# %%
df['bedRoom'].isnull().sum()
# Out:
# np.int64(49)

# %%
df = df[~df['bedRoom'].isnull()]

# %%
df.shape
# Out:
# (964, 19)

# %%
df['bedRoom'] = df['bedRoom'].str.split(' ').str.get(0).astype('int')

# %%
df.head(3)
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad               nan   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               nan   2.10
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
#
#    bedRoom      bathroom       balcony                      additionalRoom  \
# 0        5   4 Bathrooms  3+ Balconies                        Servant Room
# 1        5   4 Bathrooms   2 Balconies  Store Room,Pooja Room,Servant Room
# 2       10  10 Bathrooms  3+ Balconies                        Servant Room
#
#                                      address noOfFloor      facing  \
# ...

# %% [markdown]
# ### Checking bathroom column

# %%
df['bathroom'].value_counts()
# Out:
# bathroom
# 4 Bathrooms     228
# 3 Bathrooms     165
# 5 Bathrooms     137
# 2 Bathrooms     114
# 6 Bathrooms      82
# 1 Bathroom       65
# 9 Bathrooms      42
# 7 Bathrooms      39
# 8 Bathrooms      28
# 12 Bathrooms     22
# 10 Bathrooms     11
# 16 Bathrooms      8
# 13 Bathrooms      4
# 18 Bathrooms      4
# 11 Bathrooms      4
# 17 Bathrooms      3
# 20 Bathrooms      3
# 14 Bathrooms      2
# 21 Bathrooms      1
# 34 Bathrooms      1
# 36 Bathrooms      1
# Name: count, dtype: int64

# %%
df['bathroom'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).astype('int')

# %%
df.head(3)
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad               nan   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               nan   2.10
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
#
#    bedRoom  bathroom       balcony                      additionalRoom  \
# 0        5         4  3+ Balconies                        Servant Room
# 1        5         4   2 Balconies  Store Room,Pooja Room,Servant Room
# 2       10        10  3+ Balconies                        Servant Room
#
#                                      address noOfFloor      facing  \
# ...

# %% [markdown]
# ### Checking balcony column

# %%
df['balcony'].value_counts()
# Out:
# balcony
# 3+ Balconies    365
# 2 Balconies     220
# 3 Balconies     159
# No Balcony      115
# 1 Balcony       105
# Name: count, dtype: int64

# %%
df['balcony'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['balcony'] = df['balcony'].str.split(' ').str.get(0).str.replace('No','0')

# %%
df.head(3)
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad               nan   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               nan   2.10
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
#
#    bedRoom  bathroom balcony                      additionalRoom  \
# 0        5         4      3+                        Servant Room
# 1        5         4       2  Store Room,Pooja Room,Servant Room
# 2       10        10      3+                        Servant Room
#
#                                      address noOfFloor      facing  \
# ...

# %% [markdown]
# ### Checking additionalRoom column

# %%
df['additionalRoom'].value_counts()
# Out:
# additionalRoom
# Servant Room                                     81
# Pooja Room,Study Room,Servant Room,Store Room    60
# Others                                           58
# Pooja Room                                       38
# Pooja Room,Study Room,Servant Room               33
# Pooja Room,Study Room,Servant Room,Others        32
# Store Room                                       31
# Pooja Room,Servant Room                          24
# Study Room                                       19
# Study Room,Servant Room                          19
# Servant Room,Store Room                          15
# Pooja Room,Study Room                            11
# Pooja Room,Others                                11
# Pooja Room,Store Room                            11
# Servant Room,Others                               8
# Pooja Room,Store Room,Study Room,Servant Room     8
# Servant Room,Pooja Room                           8
# Pooja Room,Servant Room,Store Room                7
# ...

# %%
df['additionalRoom'].value_counts().shape
# Out:
# (56,)

# %%
df['additionalRoom'].isnull().sum()
# Out:
# np.int64(386)

# %%
df['additionalRoom'].fillna('not available',inplace=True)
# Out:
# <ipython-input-72-37c81a970354>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['additionalRoom'].fillna('not available',inplace=True)

# %%
df['additionalRoom'] = df['additionalRoom'].str.lower()

# %%
df.head(3)
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad               nan   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               nan   2.10
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
#
#    bedRoom  bathroom balcony                      additionalRoom  \
# 0        5         4      3+                        servant room
# 1        5         4       2  store room,pooja room,servant room
# 2       10        10      3+                        servant room
#
#                                      address noOfFloor      facing  \
# ...

# %% [markdown]
# ### Checking floor num column

# %%
df['noOfFloor']
# Out:
# 0        3 Floors
# 1        2 Floors
# 2        5 Floors
# 3        5 Floors
# 4        5 Floors
# 5        4 Floors
# 6        3 Floors
# 7        4 Floors
# 8        3 Floors
# 9        4 Floors
# 10       2 Floors
# 11       3 Floors
# 12       4 Floors
# 13       3 Floors
# 14       3 Floors
# 15       3 Floors
# 16       3 Floors
# 17       3 Floors
# 18       3 Floors
# 19       3 Floors
# 20       3 Floors
# 21       3 Floors
# 22       2 Floors
# 23            NaN
# 24       4 Floors
# 25       3 Floors
# 26       1 Floors
# 27       3 Floors
# 28       3 Floors
# 29       3 Floors
# 30       2 Floors
# 31       3 Floors
# 32       3 Floors
# 33       1 Floors
# 34       2 Floors
# 35       3 Floors
# 36       4 Floors
# 37       1 Floors
# 38       3 Floors
# 39       3 Floors
# 40       2 Floors
# 41       1 Floors
# 42       4 Floors
# 43       4 Floors
# 44       4 Floors
# 45       4 Floors
# 46       2 Floors
# 47       3 Floors
# 48       3 Floors
# 49       2 Floors
# ...

# %%
df['noOfFloor'].isnull().sum()
# Out:
# np.int64(19)

# %%
df[df['noOfFloor'].isnull()]
# Out:
#                                           property_name  \
# 23        4 Bedroom House for sale in Sector 48 Gurgaon
# 51              8 Bedroom House for sale in Palam Vihar
# 203             3 Bedroom House for sale in DLF Phase 3
# 252             3 Bedroom House for sale in Ashok Vihar
# 270    2 Bedroom House for sale in Laxman Vihar Phase 2
# 281   3 Bedroom House for sale in New Palam Vihar Ph...
# 374            4 Bedroom House for sale in Laxman Vihar
# 397     1 Bedroom House for sale in Sushant Lok Phase 1
# 417         2 Bedroom House for sale in Bhawani Enclave
# 560               2 Bedroom House for sale in Jacobpura
# 594             6 Bedroom House for sale in DLF Phase 2
# 666              3 Bedroom House for sale in New Colony
# 709      12 Bedroom House for sale in Sector 46 Gurgaon
# 832       4 Bedroom House for sale in Sector 86 Gurgaon
# 855       4 Bedroom House for sale in Sector 48 Gurgaon
# 862     4 Bedroom House for sale in Sushant Lok Phase 1
# ...

# %%
 df['noOfFloor'] =  df['noOfFloor'].str.split(' ').str.get(0)

# %%
df.head(3)
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad               nan   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               nan   2.10
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
#
#    bedRoom  bathroom balcony                      additionalRoom  \
# 0        5         4      3+                        servant room
# 1        5         4       2  store room,pooja room,servant room
# 2       10        10      3+                        servant room
#
#                                      address noOfFloor      facing  \
# ...

# %%
df.rename(columns={'noOfFloor':'floorNum'},inplace=True)

# %%
df.head(3)
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad               nan   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               nan   2.10
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
#
#    bedRoom  bathroom balcony                      additionalRoom  \
# 0        5         4      3+                        servant room
# 1        5         4       2  store room,pooja room,servant room
# 2       10        10      3+                        servant room
#
#                                      address floorNum      facing  \
# ...

# %% [markdown]
# ### Checking facing column

# %%
df['facing'].value_counts()
# Out:
# facing
# East          178
# North-East    158
# North         109
# West           75
# North-West     44
# South-East     39
# South          34
# South-West     24
# Name: count, dtype: int64

# %%
df['facing'].isnull().sum()
# Out:
# np.int64(303)

# %%
df['facing'].fillna('NA',inplace=True)
# Out:
# <ipython-input-85-e6ba103970bd>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['facing'].fillna('NA',inplace=True)

# %%
df['facing'].value_counts()
# Out:
# facing
# NA            303
# East          178
# North-East    158
# North         109
# West           75
# North-West     44
# South-East     39
# South          34
# South-West     24
# Name: count, dtype: int64

# %%
df.head(3)
# Out:
#                                       property_name           society  price  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad               nan   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               nan   2.10
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
#
#    bedRoom  bathroom balcony                      additionalRoom  \
# 0        5         4      3+                        servant room
# 1        5         4       2  store room,pooja room,servant room
# 2       10        10      3+                        servant room
#
#                                      address floorNum      facing  \
# ...

# %%
df['area'] = round((df['price']*10000000)/df['price_per_sqft'])

# %%
df.insert(loc=1,column='property_type',value='house')

# %%
df.head()
# Out:
#                                       property_name property_type  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon         house
# 1  5 Bedroom House for sale in Sector 21A Faridabad         house
# 2  10 Bedroom House for sale in Sushant Lok Phase 1         house
# 3    21 Bedroom House for sale in Sector 54 Gurgaon         house
# 4  12 Bedroom House for sale in Sushant Lok Phase 1         house
#
#             society  price  price_per_sqft    area  \
# 0  bptp visionnaire   5.25         20115.0  2610.0
# 1               nan   5.70        105751.0   539.0
# 2               nan   2.10         38251.0   549.0
# 3               nan   5.00         43066.0  1161.0
# 4               nan   3.00         53763.0   558.0
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# 1   Plot area 539(50.07 sq.m.)        5         4       2
# 2       Plot area 61(51 sq.m.)       10        10      3+
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 964 entries, 0 to 1090
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    964 non-null    object
#  1   property_type    964 non-null    object
#  2   society          964 non-null    object
#  3   price            945 non-null    float64
#  4   price_per_sqft   945 non-null    float64
#  5   area             945 non-null    float64
#  6   areaWithType     964 non-null    object
#  7   bedRoom          964 non-null    int64
#  8   bathroom         964 non-null    int64
#  9   balcony          964 non-null    object
#  10  additionalRoom   964 non-null    object
#  11  address          959 non-null    object
#  12  floorNum         945 non-null    object
#  13  facing           964 non-null    object
#  14  agePossession    964 non-null    object
#  15  nearbyLocations  848 non-null    object
#  16  description      964 non-null    object
# ...

# %%
df.shape
# Out:
# (964, 20)

# %%
df.to_csv('house_cleaned_level1.csv',index=False)

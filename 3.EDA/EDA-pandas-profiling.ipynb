# %%
#installing pandas-profiling
# !pip install pycaret

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

# Load your dataset
df = pd.read_csv('/content/gurgaon_properties_cleaned_and_feature_engineering.csv')

# Initialize setup and perform EDA
setup(df, silent=True, verbose=False)
# Out:
# Found existing installation: numba 0.61.0
# Uninstalling numba-0.61.0:
#   Would remove:
#     /usr/local/bin/numba
#     /usr/local/lib/python3.11/dist-packages/numba-0.61.0.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/numba/*
# Proceed (Y/n)? Y
#   Successfully uninstalled numba-0.61.0
# ...
#   Using cached numba-0.61.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# ...
# Using cached numba-0.61.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 25.2.1 requires numba<0.61.0a0,>=0.59.1, but you have numba 0.61.0 which is incompatible.
# cuml-cu12 25.2.1 requires numba<0.61.0a0,>=0.59.1, but you have numba 0.61.0 which is incompatible.
# dask-cuda 25.2.0 requires numba<0.61.0a0,>=0.59.1, but you have numba 0.61.0 which is incompatible.
# ...

# %%
import pandas as pd
from pandas_profiling import ProfileReport

# Load your dataset
df = pd.read_csv('/content/gurgaon_properties_cleaned_and_feature_engineering.csv').drop_duplicates()

# Create the ProfileReport object
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

# Generate the report
profile.to_file("pandas_profiling_output_report.html")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-db6f037ebc89> in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 from pandas_profiling import ProfileReport
#       3
#       4 # Load your dataset
#       5 df = pd.read_csv('/content/gurgaon_properties_cleaned_and_feature_engineering.csv').drop_duplicates()
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/controller/pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
#       6
#
# ...
